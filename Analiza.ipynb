# %%
import pandas as pd

file_path = r"TSP\bin\Debug\net8.0-windows\wyniki.csv"
data = pd.read_csv(file_path, encoding="utf-8")

data
# Out:
#                            PopulationID      Czas  Generacje  Stagnacja  \
# 0  36238412-68e8-425f-b82c-e4b9c5882d05  3.598096        100         20
# 1  0909004d-73e8-42b4-9b1f-d1385b30face  0.001109        100         20
#
#    OstatniaGeneracja  Fitness  Populacja  Geny   Selekcja Krzyżowanie  \
# 0                 69      260         10    10  ruletkowa  porządkowe
# 1                 50      209         10    10  ruletkowa  porządkowe
#
#           Mutacja  ProcentRodzicow  ProcentMutacji  ProcentKrzyzowania  \
# 0  zamiana miejsc              0.1             0.1                 0.9
# 1  zamiana miejsc              0.1             0.1                 0.9
#
#    IsQuick
# 0    False
# 1     True
